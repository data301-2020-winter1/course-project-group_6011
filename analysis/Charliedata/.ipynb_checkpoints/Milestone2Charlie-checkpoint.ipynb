# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sys,os
sys.path.insert(0,os.path.abspath('..'))
from Scripts import project_functions

# %% [markdown]
# **Load Data into dataframe**

# %%
df = pd.read_csv('adult.data')
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
df1 = project_functions.load_and_proccess(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9794d0298d9c> in <module>
# ----> 1 df1 = project_functions.load_and_proccess(df)
#
# NameError: name 'project_functions' is not defined

# %% [markdown]
# **EDA**
#     -Describing the data type of each column

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education-Num   32560 non-null  int64
#  5   Marital-Status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Realtionship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital-Gain    32560 non-null  int64
#  11  Capital-Loss    32560 non-null  int64
#  12  Hours-Per-Week  32560 non-null  int64
#  13  Native-Country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
#     -Head provides first 5 entries of the data

# %%
df1.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education-Num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-Status          Occupation    Realtionship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital-Gain  Capital-Loss  Hours-Per-Week  Native-Country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
#     -Listing the number of duplicate entries for each head item

# %%
if len(df1[df1.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(df1[df1.duplicated()]))
    print(df1[df1.duplicated(keep=False)].sort_values(by=list(df.columns)).head())
else:
    print("No duplicated entries found")
# Out:
# No. of duplicated entries:  24
#        Age Workclass  fnlwgt      Education  Education-Num  Marital-Status  \
# 17672   19   Private   97261        HS-grad              9   Never-married
# 18697   19   Private   97261        HS-grad              9   Never-married
# 6989    19   Private  138153   Some-college             10   Never-married
# 21317   19   Private  138153   Some-college             10   Never-married
# 15188   19   Private  146679   Some-college             10   Never-married
#
#              Occupation    Realtionship    Race      Sex  Capital-Gain  \
# 17672   Farming-fishing   Not-in-family   White     Male             0
# 18697   Farming-fishing   Not-in-family   White     Male             0
# 6989       Adm-clerical       Own-child   White   Female             0
# 21317      Adm-clerical       Own-child   White   Female             0
# 15188   Exec-managerial       Own-child   Black     Male             0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f04256788df1> in <module>
# ----> 1 df1.plot(df['Age'], df['Capital-Gain'])
#
# NameError: name 'df1' is not defined
